# %% [markdown]
# ## Pre-processing and Training Development
#
# This notebook is meant to do the pre-processing work to prepare the data for fitting models.  Dummy features will replace ategorical features, such as 'Signed Using'.  Additionally, data will be standardized and train and test splits will be created.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('NBA data for preprocessing', index_col=0)
df.head()
# Out:
#             Player Pos  Age   G  GS   MP   FG   FGA    FG%   3P  ...  AST  \
# 118   Aaron Gordon  PF   25  19  19  552  5.9  13.9  0.427  2.0  ...  5.2
# 277  Aaron Holiday  PG   24  29   6  576  5.1  13.7  0.370  1.9  ...  3.3
# 364     Al Horford   C   34  19  19  536  7.5  16.6  0.453  2.8  ...  4.6
# 361     Alec Burks  SG   29  18   3  459  5.0  12.7  0.395  2.8  ...  3.0
# 305    Alex Caruso  PG   26  22   0  412  3.9   8.5  0.464  1.9  ...  4.4
#
#      STL  BLK  TOV   PF   PTS       Signed Using  Team_Value  Market Size  \
# 118  0.9  1.0  3.5  2.5  17.1  Early Bird Rights       1.460        small
# 277  0.9  0.2  1.4  3.1  13.4     1st Round Pick       1.550        small
# 364  1.2  1.1  1.6  2.2  18.7          Cap Space       2.075       medium
# 361  1.2  0.4  1.6  2.4  15.6     Minimum Salary       2.075       medium
# 305  1.9  0.3  2.2  3.1  10.7     Room Exception       4.600        large
#
#      Salary (millions)
# 118          19.863636
# 277           2.239200
# 364          28.000000
# 361           2.320044
# 305           2.750000
#
# [5 rows x 31 columns]

# %%
# create dummy features to replace categorical features, exclude names because we want to keep those as identifiers
df_no_name = df.drop(['Player'], axis=1)
dfo=df_no_name.select_dtypes(include=['object'])
df = pd.concat([df.drop(dfo, axis=1), pd.get_dummies(dfo)], axis=1)
df.head()
# Out:
#             Player  Age   G  GS   MP   FG   FGA    FG%   3P  3PA  ...  \
# 118   Aaron Gordon   25  19  19  552  5.9  13.9  0.427  2.0  5.5  ...
# 277  Aaron Holiday   24  29   6  576  5.1  13.7  0.370  1.9  5.8  ...
# 364     Al Horford   34  19  19  536  7.5  16.6  0.453  2.8  7.1  ...
# 361     Alec Burks   29  18   3  459  5.0  12.7  0.395  2.8  6.9  ...
# 305    Alex Caruso   26  22   0  412  3.9   8.5  0.464  1.9  4.4  ...
#
#      Signed Using_MLE  Signed Using_Maximum Salary  \
# 118                 0                            0
# 277                 0                            0
# 364                 0                            0
# 361                 0                            0
# 305                 0                            0
#
#      Signed Using_Minimum Salary  Signed Using_Non-Bird Exception  \
# 118                            0                                0
# 277                            0                                0
# 364                            0                                0
# 361                            1                                0
# 305                            0                                0
#
#      Signed Using_Room Exception  Signed Using_Sign and Trade  \
# 118                            0                            0
# 277                            0                            0
# 364                            0                            0
# 361                            0                            0
# 305                            1                            0
#
#      Signed Using_Unknown  Market Size_large  Market Size_medium  \
# 118                     0                  0                   0
# 277                     0                  0                   0
# 364                     0                  0                   1
# 361                     0                  0                   1
# 305                     0                  1                   0
#
#      Market Size_small
# 118                  1
# 277                  1
# 364                  0
# 361                  0
# 305                  0
#
# [5 rows x 48 columns]

# %% [markdown]
# The numerical features vary significantly in magnitute, as shown in the EDA notebook.  The features need to be scaled.  First the data will be split into train/test sets.  The scaler will be fit using the training data and then the scaler will be applied to the training and testing set.

# %%
# Create train/test split.  X will be all data except salary (what will be predicted) and name.  Y will be salary.
X = df.drop(columns=['Salary (millions)', 'Player'], axis=1)
y = df['Salary (millions)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (216, 46) (72, 46) (216,) (72,)

# %%
# Initiate the scaler and fit to X_train
scaler = StandardScaler()
scaler = scaler.fit(X_train)
print(scaler)
# Out:
# StandardScaler()

# %%
# Transform the train data
X_train_scaled = scaler.transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
print(X_train_scaled)
# Out:
#           Age         G        GS        MP        FG       FGA       FG%  \
# 0    1.174107 -0.225447 -1.284037 -0.057681  0.633261 -0.114741  1.466255
# 1    0.161703  0.706545  1.299097  1.635966 -0.211394  0.488521 -1.153667
# 2   -0.091398 -0.225447  0.916410  0.735608  1.875400  1.418549  0.792561
# 3   -0.597600 -1.623435  0.342380 -0.359422  2.074143  1.368277  1.104457
# 4    1.680309 -2.322430  0.055366 -1.142977  0.037034 -0.240420  0.480666
# ..        ...       ...       ...       ...       ...       ...       ...
# 211 -0.850701  0.007551 -0.518664 -0.189084 -0.459822 -0.114741 -0.791868
# 212 -0.850701  0.706545  1.299097  1.056816  0.682947  0.940967 -0.280359
# 213 -1.356902 -1.856434 -0.805679 -0.923971  0.434519 -0.441507  1.927861
# 214  1.680309  0.473547 -0.805679  0.540936 -0.857306 -0.692866 -0.542352
# 215 -0.597600  0.939543  1.394768  1.957174  2.272885  1.468821  1.254166
#
#            3P       3PA       3P%  ...  Signed Using_MLE  \
# 0   -1.323787 -1.300728 -0.818643  ...         -0.353553
# 1    1.949984  2.054091  0.401882  ...         -0.353553
# 2   -0.893028 -0.771020 -0.335701  ...         -0.353553
# 3    0.313098  0.076513  0.788236  ...         -0.353553
# 4    0.226946  0.217769  0.480909  ...         -0.353553
# ..        ...       ...       ...  ...               ...
# 211 -0.634572 -0.241311 -0.713274  ...          2.828427
# 212 -0.548420 -0.382567 -0.142525  ...         -0.353553
# 213 -1.496091 -1.653867 -0.713274  ...         -0.353553
# 214  0.140794  0.217769  0.252609  ...         -0.353553
# 215 -0.289965 -0.417881  0.621401  ...         -0.353553
#
#      Signed Using_Maximum Salary  Signed Using_Minimum Salary  \
# 0                      -0.068199                    -0.353553
# 1                      -0.068199                    -0.353553
# 2                      -0.068199                    -0.353553
# 3                      -0.068199                     2.828427
# 4                      -0.068199                    -0.353553
# ..                           ...                          ...
# 211                    -0.068199                    -0.353553
# 212                    -0.068199                    -0.353553
# 213                    -0.068199                    -0.353553
# 214                    -0.068199                    -0.353553
# 215                    -0.068199                    -0.353553
#
#      Signed Using_Non-Bird Exception  Signed Using_Room Exception  \
# 0                          -0.096674                    -0.196116
# 1                          -0.096674                    -0.196116
# 2                          -0.096674                    -0.196116
# 3                          -0.096674                    -0.196116
# 4                          -0.096674                    -0.196116
# ..                               ...                          ...
# 211                        -0.096674                    -0.196116
# 212                        -0.096674                    -0.196116
# 213                        -0.096674                    -0.196116
# 214                        -0.096674                     5.099020
# 215                        -0.096674                    -0.196116
#
#      Signed Using_Sign and Trade  Signed Using_Unknown  Market Size_large  \
# 0                       -0.18301             -0.208514           1.576030
# 1                       -0.18301             -0.208514          -0.634506
# 2                       -0.18301             -0.208514           1.576030
# 3                       -0.18301             -0.208514          -0.634506
# 4                       -0.18301              4.795832          -0.634506
# ..                           ...                   ...                ...
# 211                     -0.18301             -0.208514          -0.634506
# 212                     -0.18301             -0.208514          -0.634506
# 213                     -0.18301             -0.208514           1.576030
# 214                     -0.18301             -0.208514           1.576030
# 215                     -0.18301             -0.208514          -0.634506
#
#      Market Size_medium  Market Size_small
# 0             -0.902843          -0.598741
# 1              1.107612          -0.598741
# 2             -0.902843          -0.598741
# 3             -0.902843           1.670172
# 4              1.107612          -0.598741
# ..                  ...                ...
# 211           -0.902843           1.670172
# 212            1.107612          -0.598741
# 213           -0.902843          -0.598741
# 214           -0.902843          -0.598741
# 215            1.107612          -0.598741
#
# [216 rows x 46 columns]

# %%
# Transform the test data
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
print(X_test_scaled)
# Out:
#          Age         G        GS        MP        FG       FGA       FG%  \
# 0  -0.344499 -0.458445 -1.284037 -0.933704 -1.006363 -1.044769 -0.068270
# 1   0.667905  0.473547  1.203425  1.548363  1.130117  1.066647  0.206198
# 2  -0.850701  1.172541 -0.614336  0.171059 -0.509507 -0.516915 -0.080746
# 3   1.427208 -0.225447  0.916410  0.341397  0.533890  0.714744 -0.242932
# 4   0.667905  0.473547  1.203425  0.594471 -0.261079 -0.893954  1.578538
# ..       ...       ...       ...       ...       ...       ...       ...
# 67 -1.610003 -0.924441  0.055366  0.404665  0.434519  0.714744 -0.405118
# 68 -0.597600  0.706545 -0.997022  0.472801 -0.062337 -0.215284  0.243625
# 69 -1.610003  0.706545  1.299097  0.954614 -0.310765  0.061211 -0.754441
# 70 -0.597600 -0.225447 -1.188366 -1.172178 -0.459822 -0.215284 -0.617207
# 71 -0.850701 -1.623435 -1.284037 -1.332782 -0.559193 -0.592323 -0.018367
#
#           3P       3PA       3P%  ...  Signed Using_MLE  \
# 0   0.054643 -0.205998  0.955070  ...         -0.353553
# 1   0.313098  0.111827  0.797016  ...         -0.353553
# 2   0.657706  0.323711  0.972632  ...         -0.353553
# 3   1.346921  1.171244  0.691647  ...         -0.353553
# 4  -1.582243 -1.689180 -2.908463  ...         -0.353553
# ..       ...       ...       ...  ...               ...
# 67  0.313098  0.535594  0.068213  ...         -0.353553
# 68 -0.117661 -0.170684  0.524813  ...         -0.353553
# 69  0.399250  0.712163 -0.072279  ...         -0.353553
# 70 -0.289965  0.005886 -0.274236  ...         -0.353553
# 71 -0.203813 -0.347253  0.647743  ...          2.828427
#
#     Signed Using_Maximum Salary  Signed Using_Minimum Salary  \
# 0                     -0.068199                    -0.353553
# 1                     -0.068199                    -0.353553
# 2                     -0.068199                    -0.353553
# 3                     -0.068199                    -0.353553
# 4                     -0.068199                    -0.353553
# ..                          ...                          ...
# 67                    -0.068199                    -0.353553
# 68                    -0.068199                     2.828427
# 69                    -0.068199                     2.828427
# 70                    -0.068199                     2.828427
# 71                    -0.068199                    -0.353553
#
#     Signed Using_Non-Bird Exception  Signed Using_Room Exception  \
# 0                         -0.096674                     5.099020
# 1                         -0.096674                    -0.196116
# 2                         -0.096674                    -0.196116
# 3                         -0.096674                    -0.196116
# 4                         -0.096674                    -0.196116
# ..                              ...                          ...
# 67                        -0.096674                    -0.196116
# 68                        -0.096674                    -0.196116
# 69                        -0.096674                    -0.196116
# 70                        -0.096674                    -0.196116
# 71                        -0.096674                    -0.196116
#
#     Signed Using_Sign and Trade  Signed Using_Unknown  Market Size_large  \
# 0                      -0.18301             -0.208514           1.576030
# 1                      -0.18301             -0.208514           1.576030
# 2                      -0.18301             -0.208514          -0.634506
# 3                      -0.18301             -0.208514          -0.634506
# 4                      -0.18301             -0.208514          -0.634506
# ..                          ...                   ...                ...
# 67                     -0.18301             -0.208514          -0.634506
# 68                     -0.18301             -0.208514          -0.634506
# 69                     -0.18301             -0.208514          -0.634506
# 70                     -0.18301             -0.208514          -0.634506
# 71                     -0.18301             -0.208514          -0.634506
#
#     Market Size_medium  Market Size_small
# 0            -0.902843          -0.598741
# 1            -0.902843          -0.598741
# 2            -0.902843           1.670172
# 3             1.107612          -0.598741
# 4             1.107612          -0.598741
# ..                 ...                ...
# 67            1.107612          -0.598741
# 68            1.107612          -0.598741
# 69            1.107612          -0.598741
# 70           -0.902843           1.670172
# 71            1.107612          -0.598741
#
# [72 rows x 46 columns]
