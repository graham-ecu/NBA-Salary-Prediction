# %% [markdown]
# # Pre-processing and Training Development
#
# This notebook documents the pre-processing work to prepare the data for model development.  Dummy features will replace categorical features, such as 'Signed Using'.  Additionally, data will be standardized and train and test splits will be created.

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('NBA Data post EDA', index_col=0)
df.head()
# Out:
#                 Player Pos  Age   G  GS    MP    FG   FGA    FG%   3P  ...  \
# 163      Stephen Curry  PG   32  29  29   987  10.6  21.5  0.492  5.3  ...
# 117         Chris Paul  PG   35  26  26   843   7.3  14.9  0.489  1.6  ...
# 193  Russell Westbrook  PG   32  19  19   631   7.9  19.4  0.406  1.3  ...
# 308          John Wall  PG   30  19  19   591   8.6  19.5  0.441  2.4  ...
# 329       LeBron James  PG   36  29  29  1006   9.8  19.5  0.504  2.6  ...
#
#      STL  BLK  TOV   PF   PTS       Signed Using  Team  Salary (millions)  \
# 163  1.3  0.1  3.4  2.0  31.7  Early Bird Rights   GSW          40.231758
# 117  1.4  0.3  2.6  3.0  19.1  Early Bird Rights   PHO          38.506482
# 193  0.9  0.4  5.4  3.1  20.5  Early Bird Rights   WAS          38.178000
# 308  1.2  0.8  4.0  1.6  23.6  Early Bird Rights   HOU          37.800000
# 329  1.1  0.5  3.9  1.6  26.6          Cap Space   LAL          37.436858
#
#      Team Value (Billions)  Market Size
# 163                    4.7        large
# 117                    1.7       medium
# 193                    1.8       medium
# 308                    2.5        large
# 329                    4.6        large
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Train/Test Split
#
# The numerical features vary significantly in magnitute, as shown in the EDA notebook. The features need to be scaled. First the data will be split into train/test sets. Then the categorical data will be separated, the scaler will be fit using the numerical training data and then the scaler will be applied to the training and testing set. At the end, the categorical data will be added back into the train/test data.

# %%
# Create train/test split.  X will be all data except salary (what will be predicted) and name.  Y will be salary.
X = df.drop(columns=['Salary (millions)', 'Player'], axis=1)
y = df['Salary (millions)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=24)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (238, 30) (80, 30) (238,) (80,)

# %% [markdown]
# ## Separate Categorical and Numerical Data for Processing

# %%
# Separate the categorical data
X_train_obj = X_train.select_dtypes(include=['object'])
X_test_obj = X_test.select_dtypes(include=['object'])

X_train_obj.head()
# Out:
#     Pos    Signed Using Team Market Size
# 312  PG  1st Round Pick  DAL      medium
# 268  SG             MLE  PHI      medium
# 170  PG  Minimum Salary  GSW       large
# 324  PF  1st Round Pick  LAL       large
# 306  SG  Minimum Salary  HOU       large

# %%
# Separate the numerical data
X_train_num = X_train.select_dtypes(include=['number'])
X_test_num = X_test.select_dtypes(include=['number'])

pd.set_option('max_columns', None)
X_train_num.head()
# Out:
#      Age   G  GS   MP    FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%  \
# 312   21  27  27  954  10.2  21.5  0.475  2.5  7.3  0.335  7.8  14.2  0.546
# 268   30  22  22  637   5.8  11.5  0.500  2.6  5.4  0.479  3.2   6.1  0.519
# 170   31  29   0  465   3.0   9.0  0.336  0.8  3.5  0.222  2.2   5.5  0.408
# 324   27  23  23  755   9.7  18.3  0.533  0.8  2.8  0.293  8.9  15.5  0.575
# 306   27  20   2  303   5.1  13.7  0.374  3.3  9.9  0.337  1.8   3.8  0.469
#
#       FT  FTA    FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# 312  6.7  8.5  0.795  0.9  7.9  8.8  9.6  1.0  0.7  4.3  2.2  29.6
# 268  2.2  2.3  0.975  0.3  2.1  2.4  3.3  1.0  0.3  1.8  2.1  16.3
# 170  2.9  3.3  0.884  0.5  3.6  4.0  6.0  1.8  0.3  1.9  3.3   9.8
# 324  4.4  6.2  0.715  2.2  7.0  9.2  3.3  1.5  2.0  2.1  2.0  24.7
# 306  1.5  2.1  0.722  0.8  4.3  5.1  2.3  1.4  0.1  2.5  3.1  15.1
#
#      Team Value (Billions)
# 312                  2.450
# 268                  2.075
# 170                  4.700
# 324                  4.600
# 306                  2.500

# %% [markdown]
# ## Scale Numerical Data

# %%
# Initiate the scaler and fit to X_train_num
scaler = StandardScaler()
scaler = scaler.fit(X_train_num)
print(scaler)
# Out:
# StandardScaler()

# %%
# Transform the train data
X_train_num_scaled = scaler.transform(X_train_num)
X_train_num_scaled = pd.DataFrame(X_train_num_scaled, columns=X_train_num.columns)
print(X_train_num_scaled)
# Out:
#           Age         G        GS        MP        FG       FGA       FG%  \
# 0   -1.470509  0.829981  1.345483  1.506218  2.123839  2.239854  0.113309
# 1    0.808674  0.002087  0.897741  0.336692 -0.058347 -0.308233  0.445095
# 2    1.061916  1.161138 -1.072323 -0.297877 -1.447012 -0.945255 -1.731420
# 3    0.048946  0.167666  0.987289  0.772036  1.875864  1.424466  0.883052
# 4    0.048946 -0.329070 -0.893226 -0.895552 -0.405513  0.252346 -1.227106
# ..        ...       ...       ...       ...       ...       ...       ...
# 233 -1.470509 -1.488121 -1.072323 -1.555947  0.239224 -0.435637  1.493538
# 234 -1.217267  0.167666  0.987289  0.974951  1.826269  2.188893 -0.231748
# 235  0.555431  0.995560 -0.355936  0.690870  0.586390  0.277827  0.591081
# 236 -1.470509 -0.991385 -0.445484 -0.762735 -0.256728 -0.231790 -0.099034
# 237  0.302189  0.664402 -0.982774  0.285041 -0.951060 -1.200063  0.498181
#
#            3P       3PA       3P%        2P       2PA       2P%        FT  \
# 0    0.621737  0.881972  0.071322  1.772389  1.762487  0.273097  2.485888
# 1    0.709659  0.185451  1.146704 -0.443958 -0.475212 -0.030313 -0.193108
# 2   -0.872943 -0.511069 -0.772554 -0.925772 -0.640968 -1.277665  0.223625
# 3   -0.872943 -0.767682 -0.242331  2.302385  2.121624  0.598982  1.116623
# 4    1.325115  1.835105  0.086258 -1.118498 -1.110608 -0.592183 -0.609840
# ..        ...       ...       ...       ...       ...       ...       ...
# 233 -1.048788 -0.511069 -1.183290  0.808760 -0.088449  2.779040  0.045025
# 234  0.885504  0.845313  0.474590  1.290574  1.734861 -0.479809  1.176156
# 235  0.270047  0.368746  0.220680  0.423308  0.022054  1.183327 -0.490774
# 236 -0.872943 -0.584387 -0.503709  0.230583  0.187810  0.183198 -0.252641
# 237 -1.312555 -1.464202  0.370039 -0.203050 -0.198953 -0.019075 -1.383772
#
#           FTA       FT%       ORB       DRB       TRB       AST       STL  \
# 0    2.572961  0.223583 -0.504889  1.340450  0.688509  2.772487 -0.277269
# 1   -0.478037  1.404487 -0.960342 -1.482368 -1.417811 -0.139848 -0.277269
# 2    0.014060  0.807475 -0.808524 -0.752329 -0.891231  1.108296  1.425701
# 3    1.441140 -0.301263  0.481925  0.902427  0.820154 -0.139848  0.787087
# 4   -0.576456 -0.255339 -0.580798 -0.411644 -0.529207 -0.602123  0.574216
# ..        ...       ...       ...       ...       ...       ...       ...
# 233  0.112479 -0.071643  0.785560  0.318395  0.556864 -1.249309 -0.490141
# 234  0.899833  0.820596 -0.732616  0.707750  0.161929  0.553565  0.361345
# 235 -0.527246  0.223583 -0.125345 -0.460313 -0.364651 -0.787034 -1.767368
# 236  0.112479 -1.016366  0.861469  0.318395  0.589775 -0.925716  0.148473
# 237 -1.265391 -2.807404 -0.428980 -0.557652 -0.562119  2.911169  3.128671
#
#           BLK       TOV        PF       PTS  Team Value (Billions)
# 0   -0.039405  2.649770 -0.711839  2.396014               0.200401
# 1   -0.583081 -0.246819 -0.790455  0.025537              -0.166751
# 2   -0.583081 -0.130955  0.152938 -1.132968               2.403313
# 3    1.727541  0.100772 -0.869071  1.522680               2.305405
# 4   -0.854919  0.564226 -0.004294 -0.188341               0.249355
# ..        ...       ...       ...       ...                    ...
# 233  4.581840 -0.942000  2.825885 -0.027933              -0.680763
# 234 -0.447162  0.564226 -0.947687  1.825674               0.934705
# 235 -0.854919 -0.594409 -0.475991  0.328530              -0.680763
# 236 -0.175324  0.216636  0.703251 -0.420042              -0.827624
# 237 -0.175324  0.680090 -0.554607 -1.329022              -0.680763
#
# [238 rows x 26 columns]

# %%
# Transform the test data
X_test_num_scaled = scaler.transform(X_test_num)
X_test_num_scaled = pd.DataFrame(X_test_num_scaled, columns=X_test_num.columns)
print(X_test_num_scaled)
# Out:
#          Age         G        GS        MP        FG       FGA       FG%  \
# 0  -0.710781  1.161138  1.435031  1.495150  1.280722  1.500909 -0.152120
# 1  -0.457539  0.995560 -0.982774  0.237080  1.181532  0.558117  1.188295
# 2   0.808674  0.333245  0.360451  0.458441 -0.752679 -0.308233 -1.160749
# 3   2.328129  0.498823 -1.072323 -0.331081 -0.455108  0.124942 -1.187292
# 4   1.568401 -0.163492  0.539548 -0.238847 -0.058347 -0.027943 -0.138848
# ..       ...       ...       ...       ...       ...       ...       ...
# 75 -1.217267  0.002087 -1.072323 -1.054194 -1.149441 -1.047178 -0.629891
# 76 -0.457539 -0.991385 -0.714129 -1.460023 -0.058347 -0.308233  0.445095
# 77 -0.710781 -2.316015 -1.072323 -1.828959 -0.802275 -0.486599 -0.882049
# 78 -0.457539  0.333245  1.076838  0.569122  0.834366  1.602833 -0.921863
# 79  0.302189  0.995560  0.360451  0.576500  0.536795 -0.180829  1.520081
#
#           3P       3PA       3P%        2P       2PA       2P%        FT  \
# 0   1.764727  1.688469  0.541801  0.278764  0.353565 -0.075262 -0.193108
# 1   0.006280 -0.437751  1.184043  1.146030  0.933710  0.643932 -0.847973
# 2   1.149271  1.468515  0.146001 -1.359405 -1.442120 -0.356198 -0.609840
# 3   1.413038  1.578492  0.317764 -1.214861 -1.082983 -1.367564  0.164092
# 4   2.204339  1.761787  0.840519 -1.263042 -1.359242 -0.097737 -0.967040
# ..       ...       ...       ...       ...       ...       ...       ...
# 75 -1.224633 -1.390884  0.370039 -0.443958 -0.088449 -1.075392 -0.431241
# 76 -0.521254 -0.401092 -0.092973  0.230583 -0.033198  0.812493 -0.193108
# 77 -1.576322 -0.731023 -2.430435  0.086038  0.022054  0.261860 -1.086106
# 78  0.533814  0.918631 -0.048165  0.519671  1.044213 -0.839406 -0.252641
# 79 -1.576322 -1.794133 -2.430435  1.386937  1.154717  0.666407 -0.014508
#
#          FTA       FT%       ORB       DRB       TRB       AST       STL  \
# 0  -0.330408  0.538491 -0.428980 -0.362975 -0.463385 -0.370986 -0.490141
# 1  -0.773294 -0.537444  1.241013  1.778474  1.741669 -0.833261  0.787087
# 2  -0.724085  0.571294 -0.808524  0.513072 -0.002627 -0.370986 -0.064398
# 3  -0.231988  1.384806 -1.036251 -1.141683 -1.220343 -0.648351 -1.128754
# 4  -1.019343 -0.071643 -0.808524 -1.287691 -1.187432 -0.833261 -1.128754
# ..       ...       ...       ...       ...       ...       ...       ...
# 75 -0.379617 -0.255339  1.468740  3.092545  2.729006 -0.370986 -0.915883
# 76  0.063270 -0.773624 -0.125345 -0.752329 -0.562119 -0.787034  1.638572
# 77  0.850624 -4.053914 -0.125345 -0.752329 -0.562119 -0.648351 -0.915883
# 78 -0.330408  0.256386 -0.201254 -1.190353 -0.891231 -0.186076  0.999958
# 79  0.014060 -0.045400  3.290551  2.362505  3.025207 -0.925716 -0.703012
#
#          BLK       TOV        PF       PTS  Team Value (Billions)
# 0  -0.719000 -0.246819 -0.947687  1.219687              -0.827624
# 1  -0.175324 -0.942000  0.074322  0.578054              -0.607333
# 2  -0.583081 -1.173727 -0.397375 -0.509158              -0.533903
# 3  -0.719000 -0.478546 -0.554607 -0.010110              -0.876578
# 4  -0.583081 -1.173727 -0.554607  0.096829              -0.778671
# ..       ...       ...       ...       ...                    ...
# 75  0.640190  0.216636  2.354188 -1.204260              -0.338088
# 76 -0.719000  0.448363  0.781867 -0.223987              -0.680763
# 77 -0.039405 -2.332362 -1.891080 -1.204260              -0.411519
# 78 -0.311243  0.911817  0.781867  0.595877              -0.925531
# 79  0.504271 -0.362682  0.388786  0.061183              -0.338088
#
# [80 rows x 26 columns]

# %% [markdown]
# ## Create Dummy Features for Categorical Data

# %%
# create dummy features to replace categorical features, making sure to reset the index so it matches the numerical data
X_train_obj = pd.get_dummies(X_train_obj).reset_index(drop=True)
X_test_obj = pd.get_dummies(X_test_obj).reset_index(drop=True)
X_train_obj.head(1)
# Out:
#    Pos_C  Pos_PF  Pos_PG  Pos_SF  Pos_SG  Signed Using_1st Round Pick  \
# 0      0       0       1       0       0                            1
#
#    Signed Using_Bi-Annual Exception  Signed Using_Cap Space  \
# 0                                 0                       0
#
#    Signed Using_Early Bird Rights  Signed Using_MLE  \
# 0                               0                 0
#
#    Signed Using_Maximum Salary  Signed Using_Minimum Salary  \
# 0                            0                            0
#
#    Signed Using_Non-Bird Exception  Signed Using_Room Exception  \
# 0                                0                            0
#
#    Signed Using_Sign and Trade  Signed Using_Unknown  Team_ATL  Team_BOS  \
# 0                            0                     0         0         0
#
#    Team_BRK  Team_CHI  Team_CHO  Team_CLE  Team_DAL  Team_DEN  Team_DET  \
# 0         0         0         0         0         1         0         0
#
#    Team_GSW  Team_HOU  Team_IND  Team_LAC  Team_LAL  Team_MEM  Team_MIA  \
# 0         0         0         0         0         0         0         0
#
#    Team_MIL  Team_MIN  Team_NOP  Team_NYK  Team_OKC  Team_ORL  Team_PHI  \
# 0         0         0         0         0         0         0         0
#
#    Team_PHO  Team_POR  Team_SAC  Team_SAS  Team_TOR  Team_UTA  Team_WAS  \
# 0         0         0         0         0         0         0         0
#
#    Market Size_large  Market Size_medium  Market Size_small
# 0                  0                   1                  0

# %%
# Check the shape
print(X_train_obj.shape, X_test_obj.shape)
# Out:
# (238, 49) (80, 47)

# %% [markdown]
# It looks like the training data and test data do not have the same number of dummy features.  When the data was split, there could have been some categorical data that was put into the train or test set and not the other.  When the data sets are used with models, they will need to have the same number of columns.

# %%
# Find any dummy features that are only included in one data set and add them to the other

for col in X_test_obj.columns:
    if col not in X_train_obj.columns:
        X_train_obj[col] = 0
for col in X_train_obj.columns:
    if col not in X_test_obj.columns:
        X_test_obj[col] = 0
        
print(X_train_obj.shape, X_test_obj.shape)
# Out:
# (238, 49) (80, 49)

# %%
# Sort columns so they appear in the same order in both the train and test set
X_train_obj = X_train_obj.sort_index(axis=1)
X_test_obj = X_test_obj.sort_index(axis=1)

# %% [markdown]
# ## Combine Data

# %%
# Concatenate the dummy features with the scaled numerical data
X_train = pd.concat([X_train_num_scaled, X_train_obj], axis=1)
X_test = pd.concat([X_test_num_scaled, X_test_obj], axis=1)
X_train.head(1)
# Out:
#         Age         G        GS        MP        FG       FGA       FG%  \
# 0 -1.470509  0.829981  1.345483  1.506218  2.123839  2.239854  0.113309
#
#          3P       3PA       3P%        2P       2PA       2P%        FT  \
# 0  0.621737  0.881972  0.071322  1.772389  1.762487  0.273097  2.485888
#
#         FTA       FT%       ORB      DRB       TRB       AST       STL  \
# 0  2.572961  0.223583 -0.504889  1.34045  0.688509  2.772487 -0.277269
#
#         BLK      TOV        PF       PTS  Team Value (Billions)  \
# 0 -0.039405  2.64977 -0.711839  2.396014               0.200401
#
#    Market Size_large  Market Size_medium  Market Size_small  Pos_C  Pos_PF  \
# 0                  0                   1                  0      0       0
#
#    Pos_PG  Pos_SF  Pos_SG  Signed Using_1st Round Pick  \
# 0       1       0       0                            1
#
#    Signed Using_Bi-Annual Exception  Signed Using_Cap Space  \
# 0                                 0                       0
#
#    Signed Using_Early Bird Rights  Signed Using_MLE  \
# 0                               0                 0
#
#    Signed Using_Maximum Salary  Signed Using_Minimum Salary  \
# 0                            0                            0
#
#    Signed Using_Non-Bird Exception  Signed Using_Room Exception  \
# 0                                0                            0
#
#    Signed Using_Sign and Trade  Signed Using_Unknown  Team_ATL  Team_BOS  \
# 0                            0                     0         0         0
#
#    Team_BRK  Team_CHI  Team_CHO  Team_CLE  Team_DAL  Team_DEN  Team_DET  \
# 0         0         0         0         0         1         0         0
#
#    Team_GSW  Team_HOU  Team_IND  Team_LAC  Team_LAL  Team_MEM  Team_MIA  \
# 0         0         0         0         0         0         0         0
#
#    Team_MIL  Team_MIN  Team_NOP  Team_NYK  Team_OKC  Team_ORL  Team_PHI  \
# 0         0         0         0         0         0         0         0
#
#    Team_PHO  Team_POR  Team_SAC  Team_SAS  Team_TOR  Team_UTA  Team_WAS
# 0         0         0         0         0         0         0         0

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (238, 75) (80, 75) (238,) (80,)

# %% [markdown]
# ## Save Processed Data

# %%
# Save the train/test data for future use
X_train.to_csv('NBA X_train')
X_test.to_csv('NBA X_test')
y_train.to_csv('NBA y_train')
y_test.to_csv('NBA y_test')
